# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagonishimura/Mestrado_Fundamentos_IC/blob/main/Thiago_Atividade_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Parte A**
#
# **Comando da questão**
#
# Com o mesmo dataset da Atividade 2, **faça boxplots de duas features** do dataset, conforme procedimento mostrado em sala. Para cada boxplot calcule:
# - CV
# - Curtose
# - Skewness
# - Mean
# - Moda
# - Analise os resultados.
#
# Para um desses boxplots, **introduza artificialmente outliers** e verifique o que ocorre com o boxplot e essas métricas.
#
# **Não esqueça do contexto sobre o dataset usado, com a explicação sobre ele, suas classes e features.**

# %% [markdown]
# # **Parte B**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Comando da questão**
#
# - Reproduza o mais próximo possível o exemplo do slide anterior.
# - Em seguida, aplique o linear regression do scikit-learn.
# - Use a biblioteca import “statsmodels.api as sm” para gerar a estatísticas da regressão linear.
# - A partir do b obtido, use 6 diferentes a's para plotar diferentes retas, mostrando a variação na rotação e gere também o gráfico a seguir:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Calcule o R-Squared para cada 'a' e compare com o melhor obtido pelo scikit-learn.
#
# Analise também:
# - R-squared
# - Adj. R-squared
# - F-statistic
# - Prob (F-statistic)
# - P-value
